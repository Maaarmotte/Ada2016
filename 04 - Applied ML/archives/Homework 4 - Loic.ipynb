# %% [markdown]
# http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html
# https://osf.io/w7tds/  unravelling
#
# http://nbviewer.jupyter.org/github/mathewzilla/redcard/blob/master/Crowdstorming_visualisation.ipynb
#
# Randomforest
# https://www.kaggle.com/c/titanic/details/getting-started-with-random-forests

# %%
import pandas as pd                                     # for dealing with csv import
import numpy as np                                      # arrays and other matlab like manipulation
import os                                               # for joining paths and filenames sensibly
# %matplotlib inline
import matplotlib.pyplot as plt 
from sklearn import preprocessing
from sklearn.feature_selection import RFE
from sklearn.cluster import KMeans
from sklearn import metrics
from random import shuffle
from sklearn import preprocessing

# %%
df = pd.read_csv('CrowdstormingDataJuly1st.csv')
allRefs = df.refNum.value_counts()
len(allRefs[allRefs > 21])
#df = df.iloc[:, :-9]
len(df.playerShort.unique())
# Out:
# 2053

# %%
df.head()
# Out:
#      playerShort         player             club leagueCountry    birthday  \
# 0  lucas-wilchez  Lucas Wilchez    Real Zaragoza         Spain  31.08.1983
# 1     john-utaka     John Utaka  Montpellier HSC        France  08.01.1982
# 2    abdon-prats    Abdón Prats     RCD Mallorca         Spain  17.12.1992
# 3     pablo-mari     Pablo Marí     RCD Mallorca         Spain  31.08.1993
# 4     ruben-pena     Rubén Peña  Real Valladolid         Spain  18.07.1991
#
#    height  weight              position  games  victories    ...     rater2  \
# 0   177.0    72.0  Attacking Midfielder      1          0    ...       0.50
# 1   179.0    82.0          Right Winger      1          0    ...       0.75
# 2   181.0    79.0                   NaN      1          0    ...        NaN
# 3   191.0    87.0           Center Back      1          1    ...        NaN
# 4   172.0    70.0      Right Midfielder      1          1    ...        NaN
#
#    refNum  refCountry  Alpha_3   meanIAT    nIAT     seIAT   meanExp    nExp  \
# 0       1           1      GRC  0.326391   712.0  0.000564  0.396000   750.0
# 1       2           2      ZMB  0.203375    40.0  0.010875 -0.204082    49.0
# 2       3           3      ESP  0.369894  1785.0  0.000229  0.588297  1897.0
# 3       3           3      ESP  0.369894  1785.0  0.000229  0.588297  1897.0
# 4       3           3      ESP  0.369894  1785.0  0.000229  0.588297  1897.0
#
#       seExp
# 0  0.002696
# 1  0.061504
# 2  0.001002
# 3  0.001002
# 4  0.001002
#
# [5 rows x 28 columns]

# %%
len(df.index)
# Out:
# 146028

# %%
# Display the first 10 rows of the dataset. Only 13 columns for space reasons
df.ix[:10,:13]
# Out:
#            playerShort              player               club leagueCountry  \
# 0        lucas-wilchez       Lucas Wilchez      Real Zaragoza         Spain
# 1           john-utaka          John Utaka    Montpellier HSC        France
# 2          abdon-prats         Abdón Prats       RCD Mallorca         Spain
# 3           pablo-mari          Pablo Marí       RCD Mallorca         Spain
# 4           ruben-pena          Rubén Peña    Real Valladolid         Spain
# 5         aaron-hughes        Aaron Hughes          Fulham FC       England
# 6   aleksandar-kolarov  Aleksandar Kolarov    Manchester City       England
# 7     alexander-tettey    Alexander Tettey       Norwich City       England
# 8    anders-lindegaard   Anders Lindegaard  Manchester United       England
# 9         andreas-beck        Andreas Beck    1899 Hoffenheim       Germany
# 10    antonio-rukavina    Antonio Rukavina    Real Valladolid         Spain
#
#       birthday  height  weight              position  games  victories  ties  \
# 0   31.08.1983   177.0    72.0  Attacking Midfielder      1          0     0
# 1   08.01.1982   179.0    82.0          Right Winger      1          0     0
# 2   17.12.1992   181.0    79.0                   NaN      1          0     1
# 3   31.08.1993   191.0    87.0           Center Back      1          1     0
# 4   18.07.1991   172.0    70.0      Right Midfielder      1          1     0
# 5   08.11.1979   182.0    71.0           Center Back      1          0     0
# 6   10.11.1985   187.0    80.0         Left Fullback      1          1     0
# 7   04.04.1986   180.0    68.0  Defensive Midfielder      1          0     0
# 8   13.04.1984   193.0    80.0            Goalkeeper      1          0     1
# 9   13.03.1987   180.0    70.0        Right Fullback      1          1     0
# 10  26.01.1984   177.0    74.0        Right Fullback      2          2     0
#
#     defeats  goals
# 0         1      0
# 1         1      0
# 2         0      0
# 3         0      0
# 4         0      0
# 5         1      0
# 6         0      0
# 7         1      0
# 8         0      0
# 9         0      0
# 10        0      0

# %%
df.columns.values
# Out:
# array(['playerShort', 'player', 'club', 'leagueCountry', 'birthday',
#        'height', 'weight', 'position', 'games', 'victories', 'ties',
#        'defeats', 'goals', 'yellowCards', 'yellowReds', 'redCards',
#        'photoID', 'rater1', 'rater2', 'refNum', 'refCountry', 'Alpha_3',
#        'meanIAT', 'nIAT', 'seIAT', 'meanExp', 'nExp', 'seExp'], dtype=object)

# %%
df.dtypes
# Out:
# playerShort       object
# player            object
# club              object
# leagueCountry     object
# birthday          object
# height           float64
# weight           float64
# position          object
# games              int64
# victories          int64
# ties               int64
# defeats            int64
# goals              int64
# yellowCards        int64
# yellowReds         int64
# redCards           int64
# photoID           object
# rater1           float64
# rater2           float64
# refNum             int64
# refCountry         int64
# Alpha_3           object
# meanIAT          float64
# nIAT             float64
# seIAT            float64
# meanExp          float64
# nExp             float64
# seExp            float64
# dtype: object

# %% [markdown]
# # Mean skin tone

# %% [markdown]
# We see that there aren't any players with only one skin colour rating, thus it should be alright to find the means of those who have two rating and use those for RandomForest classification.

# %%
dfnew = pd.DataFrame(df, columns=['player', 'rater1', 'rater2'])
dfnew.ix[200:300,:]
# Out:
#                    player  rater1  rater2
# 200        Sébastien Grax    0.00    0.25
# 201      Sébastien Roudet    0.00    0.25
# 202       Sigamary Diarra     NaN     NaN
# 203          Sloan Privat     NaN     NaN
# 204          Steeve Elana    0.75    0.75
# 205      Stéphane Darbion     NaN     NaN
# 206        Stéphen Drouin     NaN     NaN
# 207        Steven N'Zonzi     NaN     NaN
# 208        Sylvio Rodelin    0.50    0.50
# 209         Thiago Xavier     NaN     NaN
# 210         Thomas Ayasse     NaN     NaN
# 211        Thomas Mangani     NaN     NaN
# 212     Toifilou Maoulida    0.75    0.75
# 213     Valentin Eysseric     NaN     NaN
# 214      Vincent Muratori    0.00    0.25
# 215         Vincent Pajot    0.00    0.25
# 216          Wahbi Khazri     NaN     NaN
# 217         Wesley Lautoa     NaN     NaN
# 218        Yacine Brahimi    0.75    0.50
# 219       Yannick Cahuzac     NaN     NaN
# 220        Yohann Poulard     NaN     NaN
# 221   Yohann Thuram-Ulien     NaN     NaN
# 222      Youssef El-Arabi    0.50    0.75
# 223      Zouheir Dhaouadi     NaN     NaN
# 224        Levent Aycicek    0.25    0.25
# 225    Nico Brandenburger     NaN     NaN
# 226         Niklas Bolten     NaN     NaN
# 227  Georges Gope-Fenepej     NaN     NaN
# 228           Arthur Boka    1.00    1.00
# 229              Gervinho    0.75    0.75
# ..                    ...     ...     ...
# 271          Kossi Agassa    1.00    1.00
# 272      Mahamadou Diarra    1.00    1.00
# 273      Marouane Chamakh    0.25    0.25
# 274       Mohamed Sissoko    1.00    1.00
# 275       Obafemi Martins    1.00    1.00
# 276              Omar Daf    0.75    0.75
# 277       Sigamary Diarra     NaN     NaN
# 278     Souleymane Camara    0.75    1.00
# 279    Souleymane Diawara    1.00    1.00
# 280          Ali Al Habsi     NaN     NaN
# 281        Ashkan Dejagah    0.50    0.50
# 282         Atsuto Uchida    0.00    0.00
# 283          Brett Holman    0.00    0.00
# 284        Chu-Young Park    0.25    0.50
# 285       Claudio Pizarro    0.25    0.25
# 286           Dong-Won Ji     NaN     NaN
# 287             Du-Ri Cha    0.50    0.25
# 288        Hajime Hosogai    0.25    0.25
# 289         Heung-Min Son    0.25    0.50
# 290          Hiroki Sakai    0.25    0.25
# 291      Hiroshi Kiyotake    0.50    0.50
# 292          Ja-Cheol Koo    0.25    0.50
# 293      Jefferson Farfán    0.75    0.75
# 294          Ji-Sung Park    0.25    0.25
# 295         Makoto Hasebe    0.25    0.25
# 296        Mark Schwarzer    0.25    0.25
# 297        Masoud Shojaei    0.25    0.25
# 298          Maya Yoshida     NaN     NaN
# 299     Mitchell Langerak    0.00    0.00
# 300        Raúl Fernández     NaN     NaN
#
# [101 rows x 3 columns]

# %% [markdown]
# Generate new column which is the mean of two rater's opinions about the skin colour.

# %%
df['skinTone'] = ((df['rater1']+df['rater2'])/2).dropna()

# %%
dfnew = pd.DataFrame(df, columns=['player', 'rater1', 'rater2', 'skinTone'])
dfnew.head(10)
# Out:
#                player  rater1  rater2  skinTone
# 0       Lucas Wilchez    0.25    0.50     0.375
# 1          John Utaka    0.75    0.75     0.750
# 2         Abdón Prats     NaN     NaN       NaN
# 3          Pablo Marí     NaN     NaN       NaN
# 4          Rubén Peña     NaN     NaN       NaN
# 5        Aaron Hughes    0.25    0.00     0.125
# 6  Aleksandar Kolarov    0.00    0.25     0.125
# 7    Alexander Tettey    1.00    1.00     1.000
# 8   Anders Lindegaard    0.25    0.25     0.250
# 9        Andreas Beck    0.00    0.00     0.000

# %%
df = df[pd.notnull(df['skinTone'])]
df.head()
# Out:
#           playerShort              player             club leagueCountry  \
# 0       lucas-wilchez       Lucas Wilchez    Real Zaragoza         Spain
# 1          john-utaka          John Utaka  Montpellier HSC        France
# 5        aaron-hughes        Aaron Hughes        Fulham FC       England
# 6  aleksandar-kolarov  Aleksandar Kolarov  Manchester City       England
# 7    alexander-tettey    Alexander Tettey     Norwich City       England
#
#      birthday  height  weight              position  games  victories  \
# 0  31.08.1983   177.0    72.0  Attacking Midfielder      1          0
# 1  08.01.1982   179.0    82.0          Right Winger      1          0
# 5  08.11.1979   182.0    71.0           Center Back      1          0
# 6  10.11.1985   187.0    80.0         Left Fullback      1          1
# 7  04.04.1986   180.0    68.0  Defensive Midfielder      1          0
#
#      ...     refNum  refCountry  Alpha_3   meanIAT   nIAT     seIAT   meanExp  \
# 0    ...          1           1      GRC  0.326391  712.0  0.000564  0.396000
# 1    ...          2           2      ZMB  0.203375   40.0  0.010875 -0.204082
# 5    ...          4           4      LUX  0.325185  127.0  0.003297  0.538462
# 6    ...          4           4      LUX  0.325185  127.0  0.003297  0.538462
# 7    ...          4           4      LUX  0.325185  127.0  0.003297  0.538462
#
#     nExp     seExp  skinTone
# 0  750.0  0.002696     0.375
# 1   49.0  0.061504     0.750
# 5  130.0  0.013752     0.125
# 6  130.0  0.013752     0.125
# 7  130.0  0.013752     1.000
#
# [5 rows x 29 columns]

# %% [markdown]
# The number of dropped rows is not too large only around 15% of the initial dataset.

# %%
len(df.index)
# Out:
# 124621

# %%
dif = 146028-124621
percent = dif/146028 * 100
percent
# Out:
# 14.659517352836444

# %% [markdown]
# skinTone = skin rating of photo by rater (5-point scale ranging from “very light skin” to “very dark skin”)
# So, we could categorize the skinTone feature, so that over 2.5 it is dark and under it is white.

# %%
df['skinTone'].describe()
# Out:
# count    124621.000000
# mean          0.283559
# std           0.288517
# min           0.000000
# 25%           0.000000
# 50%           0.250000
# 75%           0.375000
# max           1.000000
# Name: skinTone, dtype: float64

# %% [markdown]
# As we see, the values are between 0 and 1, median being at 0.25, so there are more whites than people with dark skin.
# Alexander Tettey has a score of 1, and when we Google his name we see that he does have a very dark skin.

# %% [markdown]
# # Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Good example : https://www.kaggle.com/c/titanic/details/getting-started-with-random-forests

# %%
def map_objects(column):
    le = preprocessing.LabelEncoder()
    le.fit(column)
    return le.transform(column)

# %%
len(df.dropna())
# Out:
# 115457

# %%
df.dropna(inplace=True)

tosum = ['playerShort', 'games', 'victories', 'ties', 'defeats', 'goals', 'yellowCards', 'yellowReds', 'redCards']
tocollect = ['playerShort', 'height', 'weight', 'skinTone', 'club', 'leagueCountry', 'position'] #Justify for the 3 last columns
tomean = ['playerShort', 'meanIAT', 'meanExp',]
tomeanstd = ['playerShort', 'seIAT', 'seExp']

group1 = df[tosum].groupby('playerShort').sum()
group2 = df[tocollect].groupby('playerShort').first()
group3 = df[tomean].groupby('playerShort').mean()
group4 = df[tomeanstd].groupby('playerShort').agg(lambda x: np.sqrt(np.mean(x**2)/len(x)))

df = pd.concat([group1, group2, group3, group4], axis=1)

df.head(5)
# Out:
#                         games  victories  ties  defeats  goals  yellowCards  \
# playerShort
# aaron-hughes              654        247   179      228      9           19
# aaron-hunt                336        141    73      122     62           42
# aaron-lennon              412        200    97      115     31           11
# aaron-ramsey              260        150    42       68     39           31
# abdelhamid-el-kaoutari    124         41    40       43      1            8
#
#                         yellowReds  redCards  height  weight  skinTone  \
# playerShort
# aaron-hughes                     0         0   182.0    71.0     0.125
# aaron-hunt                       0         1   183.0    73.0     0.125
# aaron-lennon                     0         0   165.0    63.0     0.250
# aaron-ramsey                     0         1   178.0    76.0     0.000
# abdelhamid-el-kaoutari           4         2   180.0    73.0     0.250
#
#                                      club leagueCountry              position  \
# playerShort
# aaron-hughes                    Fulham FC       England           Center Back
# aaron-hunt                  Werder Bremen       Germany  Attacking Midfielder
# aaron-lennon            Tottenham Hotspur       England      Right Midfielder
# aaron-ramsey                   Arsenal FC       England     Center Midfielder
# abdelhamid-el-kaoutari    Montpellier HSC        France           Center Back
#
#                          meanIAT   meanExp     seIAT     seExp
# playerShort
# aaron-hughes            0.346459  0.494575  0.000257  0.002137
# aaron-hunt              0.348818  0.449220  0.000055  0.000252
# aaron-lennon            0.345893  0.491482  0.000126  0.000887
# aaron-ramsey            0.346821  0.514693  0.002757  0.010251
# abdelhamid-el-kaoutari  0.331600  0.335587  0.001037  0.003851

# %%
def get_sets(data, split):
    data.reindex(np.random.permutation(data.index))
    
    X_train = data[:int(len(data)*split)].select_dtypes(include=['float64', 'int64'])
    X_test = data[int(len(data)*split)+1:].select_dtypes(include=['float64', 'int64'])
    
    X_train = pd.concat([X_train, data[:int(len(data)*split)].select_dtypes(include=['object']).apply(lambda x: map_objects(x))], axis=1)
    X_test = pd.concat([X_test, data[int(len(data)*split)+1:].select_dtypes(include=['object']).apply(lambda x: map_objects(x))], axis=1)
    
    y_train = pd.cut(X_train.skinTone, [-0.1,0.50, 1], labels=[0,1])
    y_test = pd.cut(X_test.skinTone, [-0.1,0.50, 1], labels=[0,1])

    X_train.drop(['skinTone'], axis=1, inplace=True)
    X_test.drop(['skinTone'], axis=1, inplace=True)
    
    return (X_train, X_test, y_train, y_test)

def get_rfe(data):
    classifier = RandomForestClassifier()
    
    X_train, X_test, y_train, y_test = get_sets(data, 0.8)
    
    selector = RFE(classifier, step=1)
    selector.fit(X_train, y_train)
    
    return selector
    
def train_and_predict(data, use=1):
    classifier = RandomForestClassifier(scorer=)
    data.reindex(np.random.permutation(data.index))
    
    X_train, X_test, y_train, y_test = get_sets(data, 0.8)

    classifier.fit(X_train[:int(len(X_train)*use)], y_train[:int(len(X_train)*use)])

    precision = classifier.predict(X_test) == y_test
    precision = precision.value_counts()

    return precision[True]/sum(precision)

Xy = df
print(train_and_predict(Xy))
selector = get_rfe(Xy)
# Out:
# 0.883392226148

# %%
f = pd.DataFrame()
f['column'] = Xy.columns.drop('skinTone')
f['importance'] = selector.ranking_
f['support'] = selector.support_
f.sort_values(by='importance', ascending=True)
# Out:
#            column  importance support
# 0           games           1    True
# 1       victories           1    True
# 4           goals           1    True
# 5     yellowCards           1    True
# 13        meanIAT           1    True
# 12       position           1    True
# 10           club           1    True
# 11  leagueCountry           1    True
# 14        meanExp           2   False
# 2            ties           3   False
# 9          weight           4   False
# 3         defeats           5   False
# 8          height           6   False
# 15          seIAT           7   False
# 16          seExp           8   False
# 7        redCards           9   False
# 6      yellowReds          10   False

# %%
def ber(truth, predicted, classes):
    errors = 0
    lengths = [len(truth[truth == c]) for c in classes]
    n = len(truth)
    
    
    for c in classes:
        classError = 0  # Use a second variable to avoid float precision error when doing += 1/n
        for i in range(n):
            if predicted[i] != truth[i] and c == truth[i]:
                classError += 1
        if lengths[c]>0:
            errors += classError/lengths[c]
            
    return errors/len(classes)

# %%
def myscorer(clf, X, y):
    return 1 - ber(y, clf.predict(X), [0, 1])

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.001, 1.0, 30)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring=myscorer)
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import learning_curve

features1 = f[f.importance == 1].column.append(pd.Series('skinTone'))
features2 = f[f.importance != 1].column.append(pd.Series('skinTone'))

set1 = df[features1]
set2 = df[features2]

X_train, X_test, y_train, y_test = get_sets(set1, 0.8)

X_data = pd.concat([X_train, X_test])
Y_data = pd.concat([y_train, y_test])  #Labels

# %%
class_weight = np.array([6 if i == 0 else 1 for i in Y_data])
class_weight
# Out:
# array([6, 6, 6, ..., 1, 6, 6])

# %%
title = "Learning Curves (Random Forest)"

# Cross validation with 50 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set. class_weight = np.array([6 if i < 0.5 else 1 for i in Y_data])
cv = ShuffleSplit(n_splits=50, test_size=0.2, random_state=0)

classifier = RandomForestClassifier()
plot_learning_curve(classifier, title, X_data, Y_data, ylim=(0.40, 1.01), cv=cv, n_jobs=4)

plt.show()

# %%
features1 = f[f.importance == 1].column.append(pd.Series('skinTone'))
features2 = f[f.importance != 1].column.append(pd.Series('skinTone'))

folds = 20
cv = 10

Xy = df[features1]
Xy2 = df[features2]

average = []
average2 = []
for i in range(folds):
    results = []
    results2 = []
    for j in range(cv):
        results.append(train_and_predict(Xy, (i+1)/folds))
        results2.append(train_and_predict(Xy2, (i+1)/folds))
    
    average.append(sum(results)/len(results))
    average2.append(sum(results2)/len(results2))
    
plt.plot(average, 'r-', average2, 'b-')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-902c9602c94b> in <module>()
#      15     for j in range(cv):
#      16         results.append(train_and_predict(Xy, (i+1)/folds))
# ---> 17         results2.append(train_and_predict(Xy2, (i+1)/folds))
#      18
#      19     average.append(sum(results)/len(results))
#
# <ipython-input-19-a0883e515a2e> in train_and_predict(data, use)
#      32     X_train, X_test, y_train, y_test = get_sets(data, 0.8)
#      33
# ---> 34     classifier.fit(X_train[:int(len(X_train)*use)], y_train[:int(len(X_train)*use)])
#      35
#      36     precision = classifier.predict(X_test) == y_test
#
# //anaconda/lib/python3.5/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if issparse(X):
#
# //anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# //anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
Xy.columns.values

# %%
df2.columns

# %% [markdown]
# # EXERCISE 2

# %%
# Compute the Balanced Error Rate
def ber(truth, predicted, classes):
    errors = 0
    lengths = [len(truth[truth == c]) for c in classes]
    n = len(truth)
    
    for c in classes:
        for i in range(n):
            if predicted[i] != truth[i] and c == truth[i]:
                errors += 1/lengths[c]
            
    return errors/len(classes)
                
# Compute Balanced Error Rate for [0, 1] classes
def compute_misclassification(skinTone, skinTone_p):
    return ber(round(skinTone), skinTone_p, [0, 1])

# Read the data, drop the NAs and keep only the features of interest
df2 = pd.read_csv('CrowdstormingDataJuly1st.csv')
df2.dropna(inplace=True)

# Aggregate referees variables after grouping by players
tosum = ['playerShort', 'yellowCards', 'yellowReds', 'redCards', 'games', 'ties', 'goals']
tocollect = ['playerShort', 'refCountry', 'rater1', 'rater2']
tomean = ['playerShort', 'meanIAT', 'meanExp']
tomeanstd = ['playerShort', 'seIAT', 'seExp']

group1 = df2[tosum].groupby('playerShort').sum()
group2 = df2[tocollect].groupby('playerShort').first()
group3 = df2[tomean].groupby('playerShort').mean()
group4 = df2[tomeanstd].groupby('playerShort').agg(lambda x: np.sqrt(np.mean(x**2)/len(x)))

df2 = pd.concat([group1, group2, group3, group4], axis=1)

# Compute the binary skinTone
skinTone = (df2['rater1']+df2['rater2'])/2
skinTone[skinTone >= 0.5] = 1

df2.drop(['rater1', 'rater2'], axis=1, inplace=True)

#df2 = df2.select_dtypes(include=['float64', 'int64']).apply(lambda x: (x - max(x))/(max(x) - min(x)) + max(x))
df3 = df2.copy()

# Run KMeans and remove one feature until no feature remains
bestBER = 1
features = []
centers = []
silhouette = 1

scaler = preprocessing.MinMaxScaler()
for n in range(1000):
    df2 = df3.copy()
    
    # Shuffle the DataFrame
    cols = df2.columns.values.tolist()
    shuffle(cols)
    df2 = df2[cols]

    while (len(df2.columns) > 0):
        fit = KMeans(2, max_iter=1000, n_init=100).fit(scaler.fit_transform(df2))
        lab = [True if v == 1 else False for v in fit.labels_]

        total = 0
        for i in range(len(skinTone)):
            total += abs(skinTone[i] - fit.labels_[i])

        err = compute_misclassification(skinTone, fit.labels_)
        #print("Misclassification: " + str(compute_misclassification(skinTone, fit.labels_)))
        #print("Count: " + str(total))
        #print(metrics.silhouette_score(df2, fit.labels_))
        
        if err < bestBER:
            bestBER = err
            features = df2.columns.values
            centers = fit.cluster_centers_
            silhouette = metrics.silhouette_score(df2, fit.labels_)
            
            print("\nBER: " + str(err))
            print("Features: " + str(features))
            print("Silhouette: " + str(silhouette))
            print("Centers: " + str(centers))

        toRemove = df2.columns[len(df2.columns)-1]
        df2.drop(toRemove, axis=1, inplace=True)

# To put results in perspective
print("Samples with skinTone >= 0.5: " + str(len(skinTone[skinTone >= 0.5])))
print("Balanced Error Rate when prediciting full white: " + str(compute_misclassification(skinTone, np.zeros(len(skinTone)))))

# %%
round(0.5)

# %%
np.round(0.5)
